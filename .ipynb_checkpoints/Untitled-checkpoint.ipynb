# %% [markdown]
# # PROYECTO 1
# ---
# ## integrantes:
# - Juan manuel Navarro
# - Mauricio Pinto
# - Francesco Uccelli
#
#
# # LIMPIEZA DE DATOS
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
df.columns
# Out:
# Index(['country', 'iso3c', 'region', 'region_orig', 'ubigeo',
#        'iso_3166_2_code', 'date', 'confirmed', 'deaths', 'recovered',
#        'total_tests', 'negative_tests', 'pcr_test_positive',
#        'serological_test_positive', 'ag_test_positive',
#        'pcr_serological_test_positive', 'zone', 'pop2020', 'surface',
#        'capital', 'altitude', 'lat', 'lon'],
#       dtype='object')

# %%
df.tail()['confirmed']
# Out:
# 11088      41537.0
# 11089      23910.0
# 11090      15652.0
# 11091      30471.0
# 11092    1853370.0
# Name: confirmed, dtype: float64

# %%
df=df[['region','lat','lon','ubigeo','date','confirmed','deaths']]

# %%
df
# Out:
#            region      lat      lon    ubigeo        date  confirmed   deaths
# 0             NaN      NaN      NaN       NaN  2020-03-06        1.0      NaN
# 1             NaN      NaN      NaN       NaN  2020-03-07        6.0      NaN
# 2             NaN      NaN      NaN       NaN  2020-03-09        9.0      NaN
# 3             NaN      NaN      NaN       NaN  2020-03-10       11.0      NaN
# 4             NaN      NaN      NaN       NaN  2020-03-11       17.0      NaN
# ...           ...      ...      ...       ...         ...        ...      ...
# 11088  SAN MARTIN  -6.0347 -76.9742  220000.0  2021-05-10    41537.0   1238.0
# 11089       TACNA -18.0019 -70.2519  230000.0  2021-05-10    23910.0    775.0
# 11090      TUMBES  -3.5711 -80.4592  240000.0  2021-05-10    15652.0    571.0
# 11091     UCAYALI  -8.3681 -74.5433  250000.0  2021-05-10    30471.0    951.0
# 11092         NaN      NaN      NaN       NaN  2021-05-10  1853370.0  64373.0
#
# [11093 rows x 7 columns]

# %%
df=df.dropna().reset_index()
df
# Out:
#       index      region      lat      lon    ubigeo        date  confirmed  \
# 0        73        LIMA -12.0453 -77.0308  150000.0  2020-03-19      194.0
# 1        87        LIMA -12.0453 -77.0308  150000.0  2020-03-20      212.0
# 2       101        LIMA -12.0453 -77.0308  150000.0  2020-03-21      241.0
# 3       104       PIURA  -5.1525 -80.6578  200000.0  2020-03-21       18.0
# 4       115        LIMA -12.0453 -77.0308  150000.0  2020-03-22      278.0
# ...     ...         ...      ...      ...       ...         ...        ...
# 9912  11087        PUNO -15.8403 -70.0281  210000.0  2021-05-10    29940.0
# 9913  11088  SAN MARTIN  -6.0347 -76.9742  220000.0  2021-05-10    41537.0
# 9914  11089       TACNA -18.0019 -70.2519  230000.0  2021-05-10    23910.0
# 9915  11090      TUMBES  -3.5711 -80.4592  240000.0  2021-05-10    15652.0
# 9916  11091     UCAYALI  -8.3681 -74.5433  250000.0  2021-05-10    30471.0
#
#       deaths
# 0        3.0
# 1        4.0
# 2        4.0
# 3        1.0
# 4        4.0
# ...      ...
# 9912   887.0
# 9913  1238.0
# 9914   775.0
# 9915   571.0
# 9916   951.0
#
# [9917 rows x 8 columns]

# %%
del df['index']

# %%
df
# Out:
#           region      lat      lon    ubigeo        date  confirmed  deaths
# 0           LIMA -12.0453 -77.0308  150000.0  2020-03-19      194.0     3.0
# 1           LIMA -12.0453 -77.0308  150000.0  2020-03-20      212.0     4.0
# 2           LIMA -12.0453 -77.0308  150000.0  2020-03-21      241.0     4.0
# 3          PIURA  -5.1525 -80.6578  200000.0  2020-03-21       18.0     1.0
# 4           LIMA -12.0453 -77.0308  150000.0  2020-03-22      278.0     4.0
# ...          ...      ...      ...       ...         ...        ...     ...
# 9912        PUNO -15.8403 -70.0281  210000.0  2021-05-10    29940.0   887.0
# 9913  SAN MARTIN  -6.0347 -76.9742  220000.0  2021-05-10    41537.0  1238.0
# 9914       TACNA -18.0019 -70.2519  230000.0  2021-05-10    23910.0   775.0
# 9915      TUMBES  -3.5711 -80.4592  240000.0  2021-05-10    15652.0   571.0
# 9916     UCAYALI  -8.3681 -74.5433  250000.0  2021-05-10    30471.0   951.0
#
# [9917 rows x 7 columns]

# %%
import datetime as dt
df['date']=pd.to_datetime(df['date'].values, format='%Y-%m-%d')

# %%
df.date.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# # LINEAR REGRESSION
# ---

# %%
groupedf = df.groupby('region')

# %%
for title, group in groupedf:
    group.plot(kind='scatter',x='date',y='deaths',title=title)
# Out:
# /home/mauricio/Downloads/Packages/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# ...
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'

# %%
for title, group in groupedf:
    group.plot(kind='scatter',x='date',y='confirmed',title=title)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
# ...
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2316                 # force the figure dpi to 72), so we need to set it again here.
#    2317                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2318                     result = print_method(
#    2319                         filename,
#    2320                         facecolor=facecolor,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1666             kwargs.pop(arg)
#    1667
# -> 1668         return func(*args, **kwargs)
#    1669
#    1670     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     445                          else deprecation_addendum,
#     446                 **kwargs)
# --> 447         return func(*inner_args, **inner_kwargs)
#     448
#     449     return wrapper
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     505         """
#     506         FigureCanvasAgg.draw(self)
# --> 507         mpl.image.imsave(
#     508             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     509             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1606             else:
#    1607                 metadata = {
# -> 1608                     "Software": (f"Matplotlib version{mpl.__version__}, "
#    1609                                  f"https://matplotlib.org/"),
#    1610                     **(metadata if metadata is not None else {}),
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/matplotlib-3.4.1.post508+g7a12f32d8-py3.8-linux-x86_64.egg/matplotlib/__init__.py in __getattr__(name)
#     133 def __getattr__(name):
#     134     if name == "__version__":
# --> 135         import setuptools_scm
#     136         global __version__  # cache it.
#     137         # Only shell out to a git subprocess if really needed, and not on a
#
# ModuleNotFoundError: No module named 'setuptools_scm'

# %%
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## Analisis de casos

# %%
df.columns
# Out:
# Index(['region', 'lat', 'lon', 'ubigeo', 'date', 'confirmed', 'deaths'], dtype='object')

# %%
amazonas_df = df[df['region']=='AMAZONAS']

# %%
def to_seconds (date):
    return (date - np.datetime64('1970-01-01')) / np.timedelta64(1, 's')

amazonas_df.date.to_seconds ())
# Out:
# 505    2020-05-02
# 525    2020-05-03
# 545    2020-05-05
# 567    2020-05-06
# 589    2020-05-07
#           ...
# 9787   2021-05-06
# 9813   2021-05-07
# 9839   2021-05-08
# 9865   2021-05-09
# 9891   2021-05-10
# Name: date, Length: 367, dtype: datetime64[ns]

# %%
amazonas_df
# Out:
#         region     lat      lon   ubigeo       date  confirmed  deaths
# 505   AMAZONAS -6.2294 -77.8728  10000.0 2020-05-02      136.0     1.0
# 525   AMAZONAS -6.2294 -77.8728  10000.0 2020-05-03      155.0     1.0
# 545   AMAZONAS -6.2294 -77.8728  10000.0 2020-05-05      170.0     4.0
# 567   AMAZONAS -6.2294 -77.8728  10000.0 2020-05-06      176.0     5.0
# 589   AMAZONAS -6.2294 -77.8728  10000.0 2020-05-07      186.0     7.0
# ...        ...     ...      ...      ...        ...        ...     ...
# 9787  AMAZONAS -6.2294 -77.8728  10000.0 2021-05-06    26768.0   467.0
# 9813  AMAZONAS -6.2294 -77.8728  10000.0 2021-05-07    26842.0   470.0
# 9839  AMAZONAS -6.2294 -77.8728  10000.0 2021-05-08    26948.0   471.0
# 9865  AMAZONAS -6.2294 -77.8728  10000.0 2021-05-09    27011.0   474.0
# 9891  AMAZONAS -6.2294 -77.8728  10000.0 2021-05-10    27038.0   482.0
#
# [367 rows x 7 columns]

# %%
x_train=amazonas_df[['lat', 'lon', 'ubigeo', 'date']][:9000]#.to_numpy().reshape(-1,1)
y_train=amazonas_df[['confirmed']][:9000]#.to_numpy().reshape(-1,1)

# %%
x_train
# Out:
#          lat      lon   ubigeo       date
# 505  -6.2294 -77.8728  10000.0 2020-05-02
# 525  -6.2294 -77.8728  10000.0 2020-05-03
# 545  -6.2294 -77.8728  10000.0 2020-05-05
# 567  -6.2294 -77.8728  10000.0 2020-05-06
# 589  -6.2294 -77.8728  10000.0 2020-05-07
# ...      ...      ...      ...        ...
# 9787 -6.2294 -77.8728  10000.0 2021-05-06
# 9813 -6.2294 -77.8728  10000.0 2021-05-07
# 9839 -6.2294 -77.8728  10000.0 2021-05-08
# 9865 -6.2294 -77.8728  10000.0 2021-05-09
# 9891 -6.2294 -77.8728  10000.0 2021-05-10
#
# [367 rows x 4 columns]

# %%
y_train
# Out:
#       confirmed
# 505       136.0
# 525       155.0
# 545       170.0
# 567       176.0
# 589       186.0
# ...         ...
# 9787    26768.0
# 9813    26842.0
# 9839    26948.0
# 9865    27011.0
# 9891    27038.0
#
# [367 rows x 1 columns]

# %%
reg = LinearRegression().fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-b6c8e51000da> in <module>
# ----> 1 reg = LinearRegression().fit(x_train,y_train)
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/Downloads/Packages/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     531
#     532         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 533             dtype_orig = np.result_type(*dtypes_orig)
#     534
#     535     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# TypeError: invalid type promotion

# %%
reg.predict(x_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-259730a07b15> in <module>
# ----> 1 reg.predict(x_train)
#
# NameError: name 'reg' is not defined
